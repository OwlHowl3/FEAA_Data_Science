# %% [markdown]
# Sklearn has another toy regression dataset about diabetes. You can load it by calling load_diabetes() function.

# %%
# import the libraries

# %%
# load the dataset into a variable named diabetes, import the datasets from sklearn first
#datasets.load_diabetes()

# %%
# create a new dataframe from the diabetes variable


# now separate the predicted variable from the rest of the dataframe

# %%
# perform a train test split of 25% on the dataframes

# %%
# apply a linear regression using the data you have and check it's Mean Squared Error and R2

# %%
# apply a Ridge regression using the data you have and check it's Mean Squared Error and R2

# %%
# apply a Lasso regression using the data you have and check it's Mean Squared Error and R2

# %%
# apply a Elastic Net regression using the data you have and check it's Mean Squared Error and R2

# %%
# now compare the results

# %% [markdown]
# Now back to Titanic.

# %%
# load the titanic dataset

# %%
# copy the preprocessing from your previous work so you have only numeric, non-null data

# %%
# make use of SVC with different parameters 
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC - Parameters section

# %%
# try NuSVC now 
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.NuSVC.html#sklearn.svm.NuSVC - Parameters section

# %%
# and finally LinearSVC
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html#sklearn.svm.LinearSVC - Parameters section
