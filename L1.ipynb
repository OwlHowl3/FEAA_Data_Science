# %% [markdown]
# (Note : it took around 45 minutes)

# %% [markdown]
# # Hi - We are Nicu and Mihai and we do Data Science at Falcon.
#
# # It's gonna be legen... wait for it... dary! Legendary!

# %% [markdown]
# Facebook group: TO DO IN CLASS

# %% [markdown]
# Also we like python. We like python a lot, because look:
#
#
#
# ```
# print(“IE is awesome”)
# ```
# oooor, you could choose Java as well:
#
#
#
# ```
# public class HelloWorld {
#
#     public static void main(String[] args) {
#
#         System.out.println("IE is awesome");
#     }
#
# }
# ```
#
# - Ugly, hard to understand;
# - Long function lines.
#
# In other words, Python is the best programming language for a beginner.

# %% [markdown]
# ![alt text](https://i.redd.it/ry69u7oa1rsy.png)

# %% [markdown]
# ---

# %% [markdown]
# Python can do... anything... literally:
#
# * Web
#
# * Desktop GUI App
#
# * Multi-threading
#
# * System operations
#
# * ...
#
# Literally anything another programming language can do, but a little slower.
#
# Well, not quite. Even if python is a few times slower than other flagship programming languages (like Java or C++), most of the libraries are directly written in the fastest languagues out there (most of them in C/C++) and have an interface for python. This makes things actually be as fast as in C/C++, as long as you dont reinvent the wheel and make usage of the resources that are out there for you.

# %% [markdown]
# ---

# %% [markdown]
# And then, it's MAAAACHINE LEARNING... ING... ing (echoes all around).
#
# Python has the most support for the fields of Data Science and Machine Learning. Yes, there are some alternatives out there like R and MatLab; even Java is an option, but at the end of the day any programming language is possible to be used for these tasks if you REALLY want it.
#
# But, as I said before, Data Scients and Machine Learning experts have loved Python for some time and they have built a lot of great tools that work right out of the box:
#
# * NumPy - scientific library for python (Num = numbers + Py = Python); great for array operatations, creating distributions and much more
#
# * Pandas - sql in python; manages DataFrames which are table-like data storage, and Pandas can manage fast queries on the data, merging, sorting and many other operations
#
# * Matplotlib - anything that can be plotted, it can be plotted; think about anything you can do to plot data in excel -> much more
#
# * Seaborn - build on top of Matplotlib: makes it beautiful (styles and others) + many more functions and types of plots
#
# * Scikit-learn - it's a simple and efficient tool for data mining and data analysis; works perfectly with numpy, pandas, even with matplotlib; can do regression, classification, clustering, dimensionality reduction, model selection, pre-processing and much more; it implements most of the well-known predictive models & supports building neural networks
#
# And they are all open-source.

# %% [markdown]
# ![alt text](https://i.pinimg.com/originals/19/89/1b/19891b1eb9c47b70b739e06b20ba83cd.jpg)

# %% [markdown]
# **Tools for neural networks and deep learning:**
#
# * Tensorflow
#
# * Keras (build-on tensorflow)
#
# * Torch
#
# * Caffe
#
# * and many others

# %% [markdown]
# ---

# %% [markdown]
# **Also, there are a lot of cool tools to write code in. Here are some cool IDEs:**
#
# * Spider
#
# * PyCharm
#
# * Jupyter Notebooks (ipynb)
#
# * Jupyter Lab (ipynb)
#
# * Google Colab (ipynb - we are here)

# %% [markdown]
# ---

# %% [markdown]
# **Some resources to look over:**
#
# Educational Python in PyCharm - https://www.jetbrains.com/education/?fromMenu#lang=python&role=learner
#
# Python Programming Fundamentals - https://pythonprogramming.net/python-fundamental-tutorials/
#
# NumPy tutorial - http://cs231n.github.io/python-numpy-tutorial/
#
# Pandas tutorial - https://pandas.pydata.org/pandas-docs/stable/getting_started/tutorials.html
#
# and many more...
#
#
#
# **Youtube teaching channels for Data Science & Machine Learning in Python:**
#
# sentdex: https://www.youtube.com/channel/UCfzlCWGWYyIQ0aLC5w48gBQ
#
# 3blue1brown - advanced math and linear algebra: https://www.youtube.com/channel/UCYO_jab_esuFRV4b17AJtAw
#
# Arxiv Insights
# https://www.youtube.com/channel/UCNIkB2IeJ-6AmZv7bQ1oBYg
#
# Two minute papers
# https://www.youtube.com/channel/UCbfYPyITQ-7l4upoX8nvctg
#
#
#
# and, again, many more...
#
#
# **A lot of subreddits:**
#
# https://www.reddit.com/r/artificial/
#
# https://www.reddit.com/r/dataisbeautiful/
#
# https://www.reddit.com/r/deeplearning/
#
# https://www.reddit.com/r/learnmachinelearning/
#
# https://www.reddit.com/r/MachineLearning/
#
# https://www.reddit.com/r/Python/
#
# and, wow, surprise, many more...
#
#
# **Online learning platforms:**
#
# Coursera: https://www.coursera.org/
#
# Udemy: https://www.udemy.com/
#
# Datacamp: https://www.datacamp.com/

# %% [markdown]
# ---

# %% [markdown]
# Ok that's enough, let's get into things.

# %% [markdown]
# No. One more thing:

# %% [markdown]
# # Artificial Intelligence community of Iasi - Iasi AI
# - https://iasi.ai/
# - https://www.meetup.com/IASI-AI/
#
#
# ![alt text](https://secure.meetupstatic.com/photos/event/1/b/9/4/600_476467060.jpeg)
#
# Also, there is Codecamp (https://codecamp.ro/iasi) - conference about technologies, practices and trends in the IT Industry that is organized in Iasi twice a year (autumn and spring)
# and NDR (https://ndrconf.ai/) - The Artificial Conference organized in Iasi once a year (spring).

# %% [markdown]
# Okay, now it's python time!
#
# Let's become python wizzards!
#
# ![alt text](https://i.imgur.com/LLo90AU.png)
#
#
# ![alt text](https://pics.me.me/python-programming-class-42362283.png)

# %% [markdown]
# # Basics of Python

# %% [markdown]
# Today you will learn:
#
# - Python types and their manipulation: int, float, bool, string, list, dict;
#
# - Basic arithmetic operations;
#
# - Basic python functions, methods and what is a package ;
#
# - Logic and Control structures;
#
# - Loops.

# %%
#This is how you create a variable:

# integer variable
year = 3
print(year, type(year))

#float variable
grade = 10.00
print(grade, type(grade))

# string variable
name = 'IE'
print(name, type(name))

#boolean variable
awesome = True
print(awesome, type(awesome))
# Out:
# 3 <class 'int'>
# 10.0 <class 'float'>
# IE <class 'str'>
# True <class 'bool'>

# %%
# Math Operators from Highest to Lowest Precedence (number operations)
x = 5
y = 2 

## ** Exponent
print(x ** y)

# % Modulus/remainder
print(x % y)

## // Integer division/floored quotient
print(x // y)

#/ Division
print(x / y) 

# * Multiplication
print(x * y) 

# - Subtraction 
print(x - y)

# + Addition
print(x + y)
# Out:
# 25
# 1
# 2
# 2.5
# 10
# 3
# 7

# %%
# String Concatenation and Replication 
print('FEAA' + 'IE')

print('Falcon ' * 3)

print('Falcon' + str(3))

# print('Falcon' * 3.0)

# print('Falcon' * 'IE')
# Out:
# FEAAIE
# Falcon Falcon Falcon
# Falcon3

# %%
type(str(0))
# Out:
# str

# %%
str(-3.14)
# Out:
# '-3.14'

# %%
int('42')
# Out:
# 42

# %%
int('-99')
# Out:
# -99

# %%
int(1.25)
# Out:
# 1

# %%
float('3.14')
# Out:
# 3.14

# %%
# We will write a short program that says hello, asks our name and says how long it is.

print('Hello FEAA ML CLUB student!')
print('What is your name?')
myName = input()
print('It is good to meet you, ' + myName)
print('The length of your name is:')
print(len(myName))
print('What is your age?') 
myAge = input()
print('You will be ' + str(int(myAge) + 1) + ' in a year.')
print('Thanks Sherlock.')
# Out:
# Hello FEAA ML CLUB student!
# What is your name?
# Nicu
# It is good to meet you, Nicu
# The length of your name is:
# 4
# What is your age?
# 23
# You will be 24 in a year.
# Thanks Sherlock.

# %%
#As opposed to int, bool etc., a list is a compound data type; you can group values together:

a = "feaa"
b = "nice"
c = 3
my_list = [a, "is", b, c]
my_list
# Out:
# ['feaa', 'is', 'nice', 3]

# %%
# A list can contain any Python type. Although it's not really common.

any_list = ['IE', 3, 'year']
any_list

# %%
# ANY type 

# area variables (in square meters)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# house information as list of lists
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv],
         ["bedroom", bed],
         ["bathroom", bath]]

# Print out house
print(house)

# Print out the type of house
print(type(house))
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0], ['bedroom', 10.75], ['bathroom', 9.5]]
# <class 'list'>

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Print out second element from areas
print(areas[1])

# Print out last element from areas
print(areas[-1])

# Print out the area of the living room
print(areas[5])
# Out:
# 11.25
# 9.5
# 20.0

# %%
# Sum of kitchen and bedroom area: eat_sleep_area
eat_sleep_area = areas[3] + areas[7]
eat_sleep_area
# Out:
# 28.75

# %%
# Use slicing to create downstairs
downstairs = areas[0:7]
print(downstairs)

# Use slicing to create upstairs
upstairs = areas[6:10]
print(upstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bedroom']
# ['bedroom', 10.75, 'bathroom', 9.5]

# %%
# Use slicing to create downstairs
downstairs = areas[:6]
print(downstairs)

# Use slicing to create upstairs
upstairs = areas[-4:]
print(upstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom', 9.5]

# %%
#Manipulating lists
# Correct the bathroom area
areas[9] = 10.50

# Change "living room" to "chill zone"
areas[4] = "chill zone"

# Add poolhouse data to areas, new list is areas_1
areas_1 = areas + ["poolhouse", 24.5]
print(areas_1)
# Add garage data to areas_1, new list is areas_2
areas_2 = areas_1 + ["garage", 15.45]
print(areas_2)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'poolhouse', 24.5]
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'poolhouse', 24.5, 'garage', 15.45]

# %%
# Create areas_copy
# another_areas = areas
areas_copy = list(areas)

# Change areas_copy
areas_copy[0] = 5.0

# Print areas
print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5]

# %%
# Out of the box, Python offers a bunch of built-in functions. You already know two such functions: print() and type().
#You've also used the functions str(), int(), bool() and float() to switch between data types. 

var1 = [1, 2, 3, 4]
var2 = True
# Print out type of var1
print(type(var1))

# Print out length of var1
print(len(var1))

# Convert var2 to an integer: out2
out2 = int(var2)
# Out:
# <class 'list'>
# 4

# %%
#List functions 
# Create lists first and second
first = [11.25, 18.0, 20.0]
second = [10.75, 9.50]

# Paste together first and second: full
full = first + second

#Sort full
full_sorted_def = sorted(full)

# Sort full in descending order: full_sorted
full_sorted_desc = sorted(full, reverse=True)

# Print out full_sorted
print(full_sorted_def, full_sorted_desc)
# Out:
# [9.5, 10.75, 11.25, 18.0, 20.0] [20.0, 18.0, 11.25, 10.75, 9.5]

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
#Methods

# string to experiment with: place
place = "poolhouse"

# Use upper() on place: place_up
place_up = place.upper()

# Print out place and place_up
print(place, place_up)
# Out:
# poolhouse POOLHOUSE

# %%
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Print out the index of the element 20.0
print(areas.index(20.0))

# Print out how often 9.50 appears in areas
print(areas.count(9.50))
# Out:
# 2
# 1

# %%
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Use append twice to add poolhouse and garage size
areas.append(24.5)
areas.append(15.45)

# Print out areas
print(areas)

# Reverse the orders of the elements in areas
areas.reverse()

# Print out areas
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5, 24.5, 15.45]
# [15.45, 24.5, 9.5, 10.75, 20.0, 18.0, 11.25]

# %%
#Packages
# Definition of radius
r = 0.43

# Import the math package/module
import math

# Calculate C
C = 2 * math.pi * r

# Calculate A
A = math.pi * r**2

# Build printout
print("Circumference: " + str(C))
print("Area: " + str(A))
# Out:
# Circumference: 2.701769682087222
# Area: 0.5808804816487527

# %%
# Dicts

europe = { 'spain':'madrid', 'france': 'paris', 'germany' : 'berlin',
            'norway' : 'oslo'}

# Print europe
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo'}

# %%
# Print out the keys in europe
print(europe.keys())

# Print out value that belongs to key 'norway'
print(europe['norway'])
# Out:
# dict_keys(['spain', 'france', 'germany', 'norway'])
# oslo

# %%
# Add italy to europe
europe['italy'] = 'rome'
 
# Print out italy in europe
print("italy" in europe)

# Add poland to europe
europe['poland'] = 'warsaw'

# Print europe
print(europe)
# Out:
# True
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
europe = {'spain':'madrid', 'france':'paris', 'germany':'bonn',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw',
          'australia':'vienna' }

# Update capital of germany
europe['germany'] = 'berlin'

# Remove australia
del(europe['australia'])

# Print europe
print(europe)
# Out:
# {'spain': 'madrid', 'france': 'paris', 'germany': 'berlin', 'norway': 'oslo', 'italy': 'rome', 'poland': 'warsaw'}

# %%
# Dictionary of dictionaries
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }


# Print out the capital of France
print(europe['france']['capital'])

# Create sub-dictionary data
data = {'capital' : 'rome', 'population' : 59.83 }

# Add data to europe under key 'italy'
europe['italy'] = data

# Print europe
print(europe)
# Out:
# paris
# {'spain': {'capital': 'madrid', 'population': 46.77}, 'france': {'capital': 'paris', 'population': 66.03}, 'germany': {'capital': 'berlin', 'population': 80.62}, 'norway': {'capital': 'oslo', 'population': 5.084}, 'italy': {'capital': 'rome', 'population': 59.83}}

# %%
# == Equal to
# != Not equal to
# < Less than
# > Greater than
# <= Less than or equal to
# >= Greater than or equal to


# Comparison of booleans
print(True == False)

# Comparison of integers
print(-5 * 15 != 75)

# Comparison of strings
print("pyscript" == "PyScript")

# Compare a boolean with an integer
print(True == 1)

# Comparison of integers
x = -3 * 6
print(x>=-10)

# Comparison of strings
y = "test"
print("test" <= y)

# Comparison of booleans
print(True > False)
# Out:
# False
# True
# False
# True
# False
# True
# True

# %%
# Boolean operators : and &&, or || , not !

# Define variables
my_kitchen = 18.0
your_kitchen = 14.0

# my_kitchen bigger than 10 and smaller than 18?
print(my_kitchen > 10 and my_kitchen < 18)

# my_kitchen smaller than 14 or bigger than 17?
print(my_kitchen < 14 or my_kitchen > 17)

# Double my_kitchen smaller than triple your_kitchen?
print(2 * my_kitchen < 3 * your_kitchen)
# Out:
# False
# True
# True

# %%
print((4 < 5) and (5 < 6)) #
print((4 < 5) and (9 < 6)) #
print((1 == 2) or (2 == 2)) #
print(not not not not True) #
# Out:
# True
# False
# True
# True

# %%
area = 10.0
if(area < 9) :
    print("small")
elif(area < 12) :
    print("medium")
else :
    print("large")
# Out:
# medium

# %%
# Define variables
room = "bed"
area = 14.0

# if-elif-else construct for room
if room == "kit" :
    print("looking around in the kitchen.")
elif room == "bed":
    print("looking around in the bedroom.")
else :
    print("looking around elsewhere.")

# if-elif-else construct for area
if area > 15 :
    print("big place!")
elif area > 10:
    print("medium size, nice!")
else :
    print("pretty small.")
# Out:
# looking around in the bedroom.
# medium size, nice!

# %%
# basic while loop

# Initialize offset
offset = -6

# Code the while loop
while (offset != 0 ):
    print("correcting...")
    if offset > 0 :
      offset = offset -1
    else : 
      offset = offset + 1    
    print(offset)
# Out:
# correcting...
# -5
# correcting...
# -4
# correcting...
# -3
# correcting...
# -2
# correcting...
# -1
# correcting...
# 0

# %%
# for loops

# areas list
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Code the for loop
for area in areas :
    print(area)
# Out:
# 11.25
# 18.0
# 20.0
# 10.75
# 9.5

# %%
for i in range(12, 16):
  print(i)
  
print('#####')

for i in range(0, 10, 2):
  print(i)
  
print('#####')

for i in range(5, -1, -1):
  print(i)
# Out:
# 12
# 13
# 14
# 15
# #####
# 0
# 2
# 4
# 6
# 8
# #####
# 5
# 4
# 3
# 2
# 1
# 0

# %%
import random

for i in range(5):
  print(random.randint(1, 10))
# Out:
# 2
# 5
# 4
# 5
# 6

# %%
# Change for loop to use enumerate() and update print()
for key, value in enumerate(areas) :
    print("room " + str(i +1) + ": " + str(a))
# Out:
# room 5: feaa
# room 5: feaa
# room 5: feaa
# room 5: feaa
# room 5: feaa

# %%
# loop over list of lists 

# house list of lists
house = [["hallway", 11.25], 
         ["kitchen", 18.0], 
         ["living room", 20.0], 
         ["bedroom", 10.75], 
         ["bathroom", 9.50]]
         
# Build a for loop from scratch
for h in house:
    print("the " + h[0] + " is " + str(h[1]) + " sqm")
# Out:
# the hallway is 11.25 sqm
# the kitchen is 18.0 sqm
# the living room is 20.0 sqm
# the bedroom is 10.75 sqm
# the bathroom is 9.5 sqm

# %%
#loop over dictionary

# Definition of dictionary
europe = {'spain':'madrid', 'france':'paris', 'germany':'berlin',
          'norway':'oslo', 'italy':'rome', 'poland':'warsaw', 'austria':'vienna' }
          
# Iterate over europe
for k, v in europe.items() :
    print("the capital of " + k + " is " + v)
# Out:
# the capital of spain is madrid
# the capital of france is paris
# the capital of germany is berlin
# the capital of norway is oslo
# the capital of italy is rome
# the capital of poland is warsaw
# the capital of austria is vienna

# %%
#Functions

def greet(name):
  print('Hello ' + name)
  
def add(a, b):
  return a + b


greet('IE')
print(add(1,3))
# Out:
# Hello IE
# 4
